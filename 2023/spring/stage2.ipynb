# %%
# Load All Possible Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.correlation import plot_corr
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Load the dateset
df = pd.read_csv('energydata_complete.csv')

# %%
# Copy the dataset into another dataframe
df_copy = df.copy()

# %%
# Check the first few observations
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
# Check the datatypes
df.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %% [markdown]
# # Question 1
# The percent of the total variation of the dependent variable Y explained by the set of independent variables X is measured by

# %% [markdown]
# Coefficient of Determination

# %% [markdown]
# # Question 2
# How do you define a Residual?

# %% [markdown]
# Y - Y_hat

# %% [markdown]
# # Question 3
# The straight line graph of the equation Y = a + BX, the slope is horizontal if

# %% [markdown]
# b = 0

# %% [markdown]
# # Question 4
# Which of the one is true about Heteroskedasticity?

# %% [markdown]
# Linear Regression with varying error terms

# %% [markdown]
# # Question 5
# Generally, which of the following method(s) is used for predicting continuous dependent variables?
#
# 1. Linear Regression
#
# 2. Logistic Regression

# %% [markdown]
# 1 only

# %% [markdown]
# # Question 6
# From the following options below, which of these is/are true about “Ridge” or “Lasso” regression methods in case of feature selection?

# %% [markdown]
# Lasso Regression uses subset selection of features

# %% [markdown]
# # Question 7
# Which of the following sentences is/are true about outliers in Linear Regression:

# %% [markdown]
# Linear Regression is sensitive to outliers

# %% [markdown]
# # Question 8
# Which of the following metrics can be used for evaluating regression models?
#
# 1. R Squared
#
# 2. Adjusted R Squared
#
# 3. F Statistics
#
# 4. RMSE / MSE / MAE

# %% [markdown]
# 1, 2, 3, and 4

# %% [markdown]
# # Question 9
# A best fit line relating X and Y has a R-Squared value of 0.75. How do I interpret this information?

# %% [markdown]
# 75 % of the variance in Y is explained by X

# %% [markdown]
# # Question 10
# Which of the following measures is optimal for comparing the goodness of the fit of competing regression models involving the same dependent variable?

# %% [markdown]
# Standard deviation of the residuals

# %% [markdown]
# # Question 11
# The Lasso can be interpreted as least-squares linear regression where:

# %% [markdown]
# Weights are regularized with the L1 norm

# %% [markdown]
# # Question 12
# From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius (x = T2) and the temperature outside the building (y = T6). What is the R^2 value in two d.p.?

# %%
# Feature Selection for Linear Regression
X = df[["T2"]]
y = df["T6"]

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Build a Linear Regression Model
model1 = LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predications
y_pred1 = model1.predict(X_test)
print(f"r squared is: {round(r2_score(y_test, y_pred1), 2)}")
# Out:
# r squared is: 0.64

# %% [markdown]
# # Question 13
# Normalize the dataset using the MinMaxScaler after removing the following columns: [“date”, “lights”]. The target variable is “Appliances”. Use a 70-30 train-test set split with a random state of 42 (for reproducibility). Run a multiple linear regression using the training set and evaluate your model on the test set. Answer the following questions:
#
# What is the Mean Absolute Error (in two decimal places)?

# %%
# Drop the unwanted columns
df1 = df.drop(["date", "lights"], axis=1)

# Normalize the dataset with MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df1), columns=df1.columns)

# Feature Selection
X = normalised_df.drop(["Appliances"], axis=1)
y = normalised_df["Appliances"]

# Split the Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# Train the Model
model2 = LinearRegression()
model2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred2 = model2.predict(X_test)
print(f"mean absolute error is: {round(mean_absolute_error(y_test, y_pred2), 2)}")
# Out:
# mean absolute error is: 0.05

# %% [markdown]
# # Question 14
# What is the Residual Sum of Squares (in two decimal places)?

# %%
print(f"residual sum of squares is : {round(np.sum(np.square(y_test - y_pred2)), 2)}")
# Out:
# residual sum of squares is : 45.35

# %% [markdown]
# # Question 15
# What is the Root Mean Squared Error (in three decimal places)?

# %%
print(f"Root mean square error: {round(np.sqrt(mean_squared_error(y_test, y_pred2)), 3)}")
# Out:
# Root mean square error: 0.088

# %% [markdown]
# # Question 16
# What is the Coefficient of Determination (in two decimal places)?

# %%
print(f"coefficient of determination is: {round(r2_score(y_test, y_pred2), 2)}")
# Out:
# coefficient of determination is: 0.15

# %% [markdown]
# # Question 17
# Obtain the feature weights from your linear model above. Which features have the lowest and highest weights respectively?

# %%
weights_df = pd.DataFrame(data={"weights": model2.coef_}, index=X_train.columns)
weights_df
# Out:
#               weights
# T1          -0.003281
# RH_1         0.553547
# T2          -0.236178
# RH_2        -0.456698
# T3           0.290627
# RH_3         0.096048
# T4           0.028981
# RH_4         0.026386
# T5          -0.015657
# RH_5         0.016006
# T6           0.236425
# RH_6         0.038049
# T7           0.010319
# RH_7        -0.044614
# T8           0.101995
# RH_8        -0.157595
# T9          -0.189941
# RH_9        -0.039800
# T_out       -0.321860
# Press_mm_hg  0.006839
# RH_out      -0.077671
# Windspeed    0.029183
# Visibility   0.012307
# Tdewpoint    0.117758
# rv1          0.000770
# rv2          0.000770

# %%
# Feature with Maximum Weight
weights_df["weights"].idxmin()
# Out:
# 'RH_2'

# %%
# Feature with Minimum Weight
weights_df["weights"].idxmax()
# Out:
# 'RH_1'

# %% [markdown]
# # Question 18
# Train a ridge regression model with an alpha value of 0.4. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?

# %%
ridge_model = Ridge(alpha=0.4)
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
y_pred3 = ridge_model.predict(X_test)
print(f"Root mean square error: {round(np.sqrt(mean_squared_error(y_test, y_pred3)), 3)}")
# Out:
# Root mean square error: 0.088

# %%
print(f"The difference between the RMSE of both the Ridge and Linear models: {round(np.sqrt(mean_squared_error(y_test, y_pred3)), 3) - round(np.sqrt(mean_squared_error(y_test, y_pred2)), 3)}")
# Out:
# The difference between the RMSE of both the Ridge and Linear models: 0.0

# %% [markdown]
# # Question 19
# Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it. How many of the features have non-zero feature weights?

# %%
lasso_model = Lasso(alpha=0.001)
lasso_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
weights_df = pd.DataFrame(data={"weights": lasso_model.coef_}, index=X_train.columns)
weights_df
# Out:
#               weights
# T1           0.000000
# RH_1         0.017880
# T2           0.000000
# RH_2        -0.000000
# T3           0.000000
# RH_3         0.000000
# T4          -0.000000
# RH_4         0.000000
# T5          -0.000000
# RH_5         0.000000
# T6           0.000000
# RH_6        -0.000000
# T7          -0.000000
# RH_7        -0.000000
# T8           0.000000
# RH_8        -0.000110
# T9          -0.000000
# RH_9        -0.000000
# T_out        0.000000
# Press_mm_hg -0.000000
# RH_out      -0.049557
# Windspeed    0.002912
# Visibility   0.000000
# Tdewpoint    0.000000
# rv1         -0.000000
# rv2         -0.000000

# %%
np.count_nonzero(weights_df)
# Out:
# 4

# %% [markdown]
# # Question 20
# What is the new RMSE with the lasso regression? (Answer should be in three (3) decimal places)

# %%
y_pred4 = lasso_model.predict(X_test)
print(f"Root mean square error: {round(np.sqrt(mean_squared_error(y_test, y_pred4)), 3)}")
# Out:
# Root mean square error: 0.094
