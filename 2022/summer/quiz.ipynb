# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
food = pd.read_csv(r"FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
food.shape
# Out:
# (60943, 12)

# %%
food.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
food.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ["Age","Nationality","Overall"]

# %%
pd.DataFrame(lst, columns=col, index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns=col, index=[i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
array  = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
array
# Out:
# [[94, 89, 63], [93, 92, 48], [92, 94, 56]]

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             certifi             matplotlib_inline   ssl
# OpenSSL             cffi                mimetypes           sspi
# PIL                 cgi                 mistune             sspicon
# __future__          cgitb               mmap                stack_data
# _abc                charset_normalizer  mmapfile            stat
# _aix_support        chart_studio        mmsystem            statistics
# _argon2_cffi_bindings chunk               modulefinder        string
# _ast                clang               msilib              stringprep
# _asyncio            click               msvcrt              struct
# _bisect             cmath               multiprocessing     subprocess
# _black_version      cmd                 mypy_extensions     sunau
# _blake2             code                mysql               symbol
# _bootlocale         codecs              mysqlx              symtable
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][1]
x
# Out:
# 8

# %%
x = y[1][-1]
x
# Out:
# 8

# %%
food.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food.iloc(:)
# Out:
#   Input In [38]
#     food.iloc(:)
#               ^
# SyntaxError: invalid syntax

# %%
food.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food.groupby("Item")[["Y2014", "Y2017"]].sum()
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
round(food.mean(), 3), round(food.std(), 3)
# Out:
# C:\Users\Williams\AppData\Local\Temp\ipykernel_8312\1344846912.py:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (Area Code        134.266
#  Item Code       2687.177
#  Element Code    3814.856
#  Y2014            134.196
#  Y2015            135.236
#  Y2016            136.555
#  Y2017            140.918
#  Y2018            143.758
#  dtype: float64,
#  Area Code         72.606
#  Item Code        146.056
#  Element Code    2212.007
#  Y2014           1567.664
#  Y2015           1603.404
#  Y2016           1640.007
#  Y2017           1671.862
#  Y2018           1710.783
#  dtype: float64)

# %%
round(food["Y2016"].isnull().sum(), 2), round(food["Y2016"].isnull().mean()*100, 2)
# Out:
# (1535, 2.52)

# %%
food["Element Code"].corrcoef()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [82], in <module>
# ----> 1 food["Element Code"].corrcoef()
#
# File c:\users\williams\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'corrcoef'

# %%
food.groupby("Element Code").corr()
# Out:
#                         Area Code  Item Code     Y2014     Y2015     Y2016  \
# Element Code
# 511          Area Code   1.000000        NaN  0.149348  0.149792  0.150292
#              Item Code        NaN        NaN       NaN       NaN       NaN
#              Y2014       0.149348        NaN  1.000000  0.999988  0.999951
#              Y2015       0.149792        NaN  0.999988  1.000000  0.999987
#              Y2016       0.150292        NaN  0.999951  0.999987  1.000000
# ...                           ...        ...       ...       ...       ...
# 5911         Y2014       0.005901   0.056301  1.000000  0.976942  0.992694
#              Y2015       0.007883   0.050526  0.976942  1.000000  0.965195
#              Y2016       0.006203   0.062306  0.992694  0.965195  1.000000
#              Y2017       0.005156   0.063080  0.941934  0.863665  0.963790
#              Y2018       0.004272   0.063211  0.942024  0.863140  0.963378
#
#                            Y2017     Y2018
# ...

# %%
food.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
food.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
food.groupby(["Element"])["Y2018", "Element"].sum()
# Out:
# C:\Users\Williams\AppData\Local\Temp\ipykernel_8312\1159089225.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# ...

# %%
food[food["Area"]=="Algeria"].sum()
# Out:
# Area Code                                                    5252
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 3532053
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                              5017927
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                   313375.33
# Y2015                                                    324058.4
# Y2016                                                   326007.41
# Y2017                                                   325644.27
# Y2018                                                   341729.98
# dtype: object

# %%
len(food["Area"].unique())
# Out:
# 49
